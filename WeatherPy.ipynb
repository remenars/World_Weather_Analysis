# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

from citipy import citipy

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#declare empty list


# Create a list for holding the cities.
cities = []

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
#returns a zip object in memory
#zip object packs each pair of lats and lngs having the same index in their array into a tuple
#you can only unzip a zipped tuple once before it is removed from the comp's memory
#make sure you unzip into a list to save them before moving on
#Add the lats and lngs to a list
coordinates = list(lat_lngs)
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
city_data = []
print(city_data)
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# []
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | mineiros
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | huanren
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 1 | cap malheureux
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | aswan
# Processing Record 18 of Set 1 | daloa
# Processing Record 19 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | kyra
# Processing Record 22 of Set 1 | varvoru
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | hambantota
# Processing Record 25 of Set 1 | okhotsk
# Processing Record 26 of Set 1 | akyab
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | general cepeda
# Processing Record 31 of Set 1 | kysyl-syr
# Processing Record 32 of Set 1 | korla
# Processing Record 33 of Set 1 | cabra
# Processing Record 34 of Set 1 | jardim de piranhas
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | haines junction
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | yerbogachen
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | bowen
# Processing Record 45 of Set 1 | bichura
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | kamakwie
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | alta floresta
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | phan thiet
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | tura
# Processing Record 15 of Set 2 | novopokrovskaya
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | anchorage
# Processing Record 18 of Set 2 | sao felix do xingu
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | morondava
# Processing Record 23 of Set 2 | acapulco
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | strezhevoy
# Processing Record 26 of Set 2 | goycay
# City not found. Skipping...
# Processing Record 27 of Set 2 | bonavista
# Processing Record 28 of Set 2 | lata
# Processing Record 29 of Set 2 | lesosibirsk
# Processing Record 30 of Set 2 | san policarpo
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set
# Processing Record 48 of Set 3 | almaznyy
# Processing Record 49 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | newton
# Processing Record 3 of Set 4 | port macquarie
# Processing Record 4 of Set 4 | isangel
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | sidi ali
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | colwyn bay
# Processing Record 9 of Set 4 | visby
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | marsaxlokk
# Processing Record 13 of Set 4 | tessalit
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | aipe
# Processing Record 16 of Set 4 | jampur
# Processing Record 17 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | russkaya polyana
# Processing Record 22 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | gambita
# City not found. Skipping...
# Processing Record 25 of Set 4 | lagoa
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | bara
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | kidal
# Processing Record 30 of Set 4 | khandyga
# Processing Record 31 of Set 4 | santa cruz del sur
# Processing Record 32 of Set 4 | machachi
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | nhamunda
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | el carmen
# Processing Record 37 of Set 4 | inhambane
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | mackenzie
# Processing Record 41 of Set 4 | seoul
# Processing Record 42 of Set 4 | awjilah
# Processing Record 43 of Set 4 | kalemie
# Processing Record 44 of Set 4 | necochea
# Processing Record 45 of Set 4 | praya
# Processing Record 46 of Set 4 | westport
# Processing Record 47 of Set 4 | winneba
# Processing Record 48 of Set 4 | aksu
# Processing Record 49 of Set 4 | boatlaname
# City not found. Skipping...
# Processing Record 50 of Set 4 | basoko
# Processing Record 1 of Set 5 | yuci
# Processing Record 2 of Set 5 | fougamou
# Processing Record 3 of Set 5 | dalbandin
# Processing Record 4 of Set 5 | jalu
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | kulhudhuffushi
# Processing Record 8 of Set 5 | oistins
# Processing Record 9 of Set 5 | aksarka
# Processing Record 10 of Set 5 | tonneins
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | emerald
# Processing Record 13 of Set 5 | dikson
# Processing Record 14 of Set 5 | ruteng
# Processing Record 15 of Set 5 | vao
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | puerto escondido
# Processing Record 21 of Set 5 | salekhard
# Processing Record 22 of Set 5 | yelabuga
# Processing Record 23 of Set 5 | kenora
# Processing Record 24 of Set 5 | nieuw amsterdam
# Processing Record 25 of Set 5 | nakonde
# Processing Record 26 of Set 5 | bubaque
# Processing Record 27 of Set 5 | beloha
# Processing Record 28 of Set 5 | green river
# Processing Record 29 of Set 5 | takoradi
# Processing Record 30 of Set 5 | noyabrsk
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | bintulu
# Processing Record 33 of Set 5 | tambacounda
# Processing Record 34 of Set 5 | kafue
# Processing Record 35 of Set 5 | ewa beach
# Processing Record 36 of Set 5 | tofield
# Processing Record 37 of Set 5 | ocampo
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | gornopravdinsk
# Processing Record 41 of Set 5 | gisborne
# Processing Record 42 of Set 5 | rawson
# Processing Record 43 of Set 5 | lahat
# Processing Record 44 of Set 5 | yumen
# Processing Record 45 of Set 5 | mikhaylovka
# Processing Record 46 of Set 5 | heilbron
# Processing Record 47 of Set 5 | livingston
# Processing Record 48 of Set 5 | groa
# Processing Record 49 of Set 5 | namatanai
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | kruisfontein
# Processing Record 2 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 6 | shenzhen
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | tarko-sale
# Processing Record 8 of Set 6 | aguas vermelhas
# Processing Record 9 of Set 6 | salihorsk
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | byron bay
# Processing Record 12 of Set 6 | vestmannaeyjar
# Processing Record 13 of Set 6 | tiznit
# Processing Record 14 of Set 6 | campo alegre
# Processing Record 15 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 6 | luanda
# Processing Record 17 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 18 of Set 6 | luwuk
# Processing Record 19 of Set 6 | ponta do sol
# Processing Record 20 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 6 | hammerfest
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | hervey bay
# Processing Record 24 of Set 6 | serendah
# Processing Record 25 of Set 6 | laguna
# Processing Record 26 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 6 | aberdeen
# Processing Record 28 of Set 6 | lerwick
# Processing Record 29 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 6 | yerofey pavlovich
# Processing Record 31 of Set 6 | galesong
# Processing Record 32 of Set 6 | taoudenni
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | candolim
# Processing Record 35 of Set 6 | iquitos
# Processing Record 36 of Set 6 | vidim
# Processing Record 37 of Set 6 | amazar
# Processing Record 38 of Set 6 | rungata
# City not found. Skipping...
# Processing Record
of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | calmar
# Processing Record 38 of Set 9 | quelimane
# Processing Record 39 of Set 9 | salinopolis
# Processing Record 40 of Set 9 | nizhniye sergi
# Processing Record 41 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 9 | hachinohe
# Processing Record 43 of Set 9 | aktau
# Processing Record 44 of Set 9 | aojiang
# Processing Record 45 of Set 9 | kedrovyy
# Processing Record 46 of Set 9 | chima
# Processing Record 47 of Set 9 | cayenne
# Processing Record 48 of Set 9 | pimentel
# Processing Record 49 of Set 9 | juneau
# Processing Record 50 of Set 9 | semirom
# Processing Record 1 of Set 10 | port said
# Processing Record 2 of Set 10 | berdigestyakh
# Processing Record 3 of Set 10 | plainview
# Processing Record 4 of Set 10 | margate
# Processing Record 5 of Set 10 | turan
# Processing Record 6 of Set 10 | berlevag
# Processing Record 7 of Set 10 | eureka
# Processing Record 8 of Set 10 | itoman
# Processing Record 9 of Set 10 | louis trichardt
# Processing Record 10 of Set 10 | skagen
# Processing Record 11 of Set 10 | temple
# Processing Record 12 of Set 10 | soroti
# Processing Record 13 of Set 10 | govindgarh
# Processing Record 14 of Set 10 | anloga
# Processing Record 15 of Set 10 | camacha
# Processing Record 16 of Set 10 | canutama
# Processing Record 17 of Set 10 | tres picos
# Processing Record 18 of Set 10 | souflion
# City not found. Skipping...
# Processing Record 19 of Set 10 | ostrovnoy
# Processing Record 20 of Set 10 | japura
# Processing Record 21 of Set 10 | port augusta
# Processing Record 22 of Set 10 | palu
# Processing Record 23 of Set 10 | hohhot
# Processing Record 24 of Set 10 | las cruces
# Processing Record 25 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 10 | vila
# Processing Record 27 of Set 10 | oxelosund
# Processing Record 28 of Set 10 | srednekolymsk
# Processing Record 29 of Set 10 | ajdabiya
# Processing Record 30 of Set 10 | maridi
# Processing Record 31 of Set 10 | svobodnyy
# Processing Record 32 of Set 10 | sola
# Processing Record 33 of Set 10 | broken hill
# Processing Record 34 of Set 10 | talara
# Processing Record 35 of Set 10 | djambala
# Processing Record 36 of Set 10 | bathsheba
# Processing Record 37 of Set 10 | lorengau
# Processing Record 38 of Set 10 | krasnoselkup
# Processing Record 39 of Set 10 | bataipora
# Processing Record 40 of Set 10 | pundaguitan
# Processing Record 41 of Set 10 | wetaskiwin
# Processing Record 42 of Set 10 | tazovskiy
# Processing Record 43 of Set 10 | la asuncion
# Processing Record 44 of Set 10 | snyder
# Processing Record 45 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 10 | qui nhon
# Processing Record 47 of Set 10 | florianopolis
# Processing Record 48 of Set 10 | turukhansk
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | utiel
# Processing Record 1 of Set 11 | chapais
# Processing Record 2 of Set 11 | katha
# City not found. Skipping...
# Processing Record 3 of Set 11 | maltahohe
# Processing Record 4 of Set 11 | tsabong
# Processing Record 5 of Set 11 | nouakchott
# Processing Record 6 of Set 11 | bardiyah
# Processing Record 7 of Set 11 | davidson
# Processing Record 8 of Set 11 | taunggyi
# Processing Record 9 of Set 11 | nishihara
# Processing Record 10 of Set 11 | waw
# Processing Record 11 of Set 11 | manta
# Processing Record 12 of Set 11 | camargo
# Processing Record 13 of Set 11 | iquique
# Processing Record 14 of Set 11 | champerico
# Processing Record 15 of Set 11 | leningradskiy
# Processing Record 16 of Set 11 | morwell
# Processing Record 17 of Set 11 | callaway
# Processing Record 18 of Set 11 | kukuna
# Processing Record 19 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | mweka
# Processing Record 22 of Set 11 | alice springs
# Processing Record 23 of Set 11 | eldoret
# Processing Record 24 of Set 11 | puri
# Processing Record 25 of Set 11 | tall kayf
# Processing Record 26 of Set 11 | maningrida
# Processing Record 27 of Set 11 | litovko
# Processing Record 28 of Set 11 | narsaq
# Processing Record 29 of Set 11 | dunmore east
# Processing Record 30 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 11 | wattegama
# Processing Record 32 of Set 11 | kathmandu
# Processing Record 33 of Set 11 | bengkulu
# Processing Record 34 of Set 11 | novikovo
# Processing Record 35 of Set 11 | matara
# Processing Record 36 of Set 11 | talnakh
# Processing Record 37 of Set 11 | zhaotong
# Processing Record 38 of Set 11 | kamina
# Processing Record 39 of Set 11 | akhmim
# Processing Record 40 of Set 11 | oranjemund
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | padang
# Processing Record 43 of Set 11 | rio grande
# Processing Record 44 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 11 | soyo
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | karatau
# Processing Record 48 of Set 11 | mwingi
# Processing Record 49 of Set 11 | turayf
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | esperance
# Processing Record 2 of Set 12 | lazaro cardenas
# Processing Record 3 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 4 of Set 12 | ketou
# Processing Record 5 of Set 12 | eyl
# Processing Record 6 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 7 of Set 12 | datong
# Processing Record 8 of Set 12 | miles city
# Processing Record 9 of Set 12 | lewiston
# Processing Record 10 of Set 12 | soto la marina
# Processing Record 11 of Set 12 | mindelo
# Processing Record 12 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 12 | butembo
# Processing Record 14 of Set 12 | moussoro
# Processing Record 15 of Set 12 | plouzane
# Processing Record 16 of Set 12 | copiapo
# Processing Record 17 of Set 12 | lebowakgomo
# Processing Record 18 of Set 12 | dakar
# Processing Record 19 of Set 12 | lisakovsk
# Processing Record 20 of Set 12 | palana
# Processing Record 21 of Set 12 | tiptur
# Processing Record 22 of Set 12 | contai
# Processing Record 23 of Set 12 | lompoc
# Processing Record 24 of Set 12 | itaituba
# Processing Record 25 of Set 12 | chopovychi
# Processing Record 26 of Set 12 | farafangana
# Processing Record 27 of Set 12 | abu kamal
# Processing Record 28 of Set 12 | verkhoyansk
# Processing Record 29 of Set 12 | dali
# Processing Record 30 of Set 12 | dzhebariki-khaya
# Processing Record 31 of Set 12 | vardo
# Processing Record 32 of Set 12 | kondinskoye
# Processing Record 33 of Set 12 | redwater
# Processing Record 34 of Set 12 | evensk
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | ouargaye
# Processing Record 37 of Set 12 | meadow lake
# Processing Record 38 of Set 12 | demirci
# Processing Record 39 of Set 12 | chokwe
# Processing Record 40 of Set 12 | baillif
# Processing Record 41 of Set 12 | shahrud
# Processing Record 42 of Set 12 | black river
# Processing Record 43 of Set 12 | tamandare
# Processing Record 44 of Set 12 | kant
# Processing Record 45 of Set 12 | qaqortoq
# Processing Record 46 of Set 12 | bereda
# Processing Record 47 of Set 12 | matay
# Processing Record 48 of Set 12 | numan
# Processing Record 49 of Set 12 | ballesteros
# Processing Record 50 of Set 12 | dasuya
# Processing Record 1 of Set 13 | havoysund
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | oksfjord
# Processing Record 4 of Set 13 | christchurch
# Processing Record 5 of Set 13 | puerto leguizamo
# Processing Record 6 of Set 13 | tayu
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | sibolga
# Processing Record 9 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 13 | maxixe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 563

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tuatapere -46.1333  167.6833     44.19        93           6
# 1          Hasaki  35.7333  140.8333     50.40        68          67
# 2        Mineiros -17.5694  -52.5511     76.15        42           0
# 3       Upernavik  72.7868  -56.1549     -2.88        81         100
# 4         Huanren  41.2647  125.3667     48.58        49         100
# 5          Torbay  47.6666  -52.7314     42.76        92         100
# 6    Longyearbyen  78.2186   15.6401     21.04        86          75
# 7    Punta Arenas -53.1500  -70.9167     46.51        87          75
# 8         Ushuaia -54.8000  -68.3000     51.46        66          75
# 9  Cap Malheureux -19.9842   57.6142     77.47        90          38
#
#    Wind Speed Country                 Date
# 0        4.63      NZ  2022-04-17 18:43:35
# 1        8.57      JP  2022-04-17 18:43:36
# 2        6.11      BR  2022-04-17 18:43:36
# 3       15.95      GL  2022-04-17 18:43:36
# 4        2.86      CN  2022-04-17 18:43:37
# 5       28.77      CA  2022-04-17 18:43:37
# 6       10.36      SJ  2022-04-17 18:43:37
# 7        5.75      CL  2022-04-17 18:43:37
# 8        0.00      AR  2022-04-17 18:43:38
# 9        1.01      MU  2022-04-17 18:43:38

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
New_City_Data_df = city_data_df[new_column_order]
New_City_Data_df
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0                Tuatapere      NZ  2022-04-17 18:43:35 -46.1333  167.6833
# 1                   Hasaki      JP  2022-04-17 18:43:36  35.7333  140.8333
# 2                 Mineiros      BR  2022-04-17 18:43:36 -17.5694  -52.5511
# 3                Upernavik      GL  2022-04-17 18:43:36  72.7868  -56.1549
# 4                  Huanren      CN  2022-04-17 18:43:37  41.2647  125.3667
# ..                     ...     ...                  ...      ...       ...
# 558                   Tayu      ID  2022-04-17 18:58:13  -6.5397  111.0518
# 559  Los Llanos De Aridane      ES  2022-04-17 18:58:13  28.6585  -17.9182
# 560                Sibolga      ID  2022-04-17 18:58:13   1.7427   98.7792
# 561               Yar-Sale      RU  2022-04-17 18:58:14  66.8333   70.8333
# 562                 Maxixe      MZ  2022-04-17 18:58:14 -23.8597   35.3472
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       44.19        93           6        4.63
# 1       50.40        68          67        8.57
# 2       76.15        42           0        6.11
# 3       -2.88        81         100       15.95
# 4       48.58        49         100        2.86
# ..        ...       ...         ...         ...
# 558     79.74        86          79        1.43
# 559     65.95        83           0       14.97
# 560     77.79        89          95        3.44
# 561     10.74        94         100        8.03
# 562     72.28        93         100        6.17
#
# [563 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
#returns a zip object in memory
#zip object packs each pair of lats and lngs having the same index in their array into a tuple
#you can only unzip a zipped tuple once before it is removed from the comp's memory
#make sure you unzip into a list to save them before moving on

# %%
#Add the lats and lngs to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614

# %%
cities
# Out:
# ['qaanaaq',
#  'mar del plata',
#  'popondetta',
#  'khatanga',
#  'jijiga',
#  'waddan',
#  'tuatapere',
#  'punta arenas',
#  'illoqqortoormiut',
#  'jamestown',
#  'tasiilaq',
#  'santa maria da vitoria',
#  'busselton',
#  'georgetown',
#  'kurilsk',
#  'havre-saint-pierre',
#  'cidreira',
#  'albany',
#  'kodiak',
#  'atuona',
#  'barrow',
#  'ushuaia',
#  'gubin',
#  'rikitea',
#  'carnarvon',
#  'hakui',
#  'tharad',
#  'labuhan',
#  'leningradskiy',
#  'butaritari',
#  'puerto ayora',
#  'genhe',
#  'aklavik',
#  'kayerkan',
#  'mataura',
#  'lasa',
#  'pinotepa nacional',
#  'zanjan',
#  'aljezur',
#  'jaunjelgava',
#  'liverpool',
#  'katsuura',
#  'ust-uda',
#  'necochea',
#  'ilulissat',
#  'saint-philippe',
#  'bredasdorp',
#  'gurupa',
#  'cuencame',
#  'trincomalee',
#  'hovd',
#  'kapaa',
#  'codajas',
#  'manokwari',
#  'umkomaas',
#  'virginia beach',
#  'kazalinsk',
#  'vaini',
#  'flinders',
#  'hobart',
#  'dong hoi',
#  'avarua',
#  'bethel',
#  'thompson',
#  'camacha',
#  'kaitangata',
#  'saint-leu',
#  'hilo',
#  'nicolas bravo',
#  'port blair',
#  'lavrentiya',
#  'tumannyy',
#  'shahpura',
#  'esperance',
#  'bathsheba',
#  'inuvik',
#  'chokurdakh',
#  'sao felix do xingu',
#  'tiksi',
#  'axim',
#  'ust-kuyga',
#  'kruisfontein',
#  'calafell',
#  'bluff',
#  'northam',
#  'raga',
#  'lebu',
#  'upernavik',
#  'castro',
#  'ahuimanu',
#  'bonnyville',
#  'cayenne',
#  'acapulco',
#  'maldonado',
#  'peace river',
#  'rio grande',
#  'koslan',
#  'havoysund',
#  'new norfolk',
#  'tilichiki',
#  'yeppoon',
#  'baoro',
#  'warqla',
#  'hamilton',
#  'inhambane',
#  'codrington',
#  'kokologo',
#  'clyde river',
#  'tsihombe',
#  'port hardy',
#  'belushya guba',
#  'taolanaro',
#  'arraial do cabo',
#  'kologriv',
#  'kitimat',
#  'east london',
#  'amapa',
#  'komsomolskiy',
#  'kavaratti',
#  'havelock',
#  'opuwo',
#  'pachino',
#  'kibaya',
#  'port lincoln',
#  'jujuy',
#  'marrakesh',
#  'ribeira grande',
#  'bullhead city',
#  'geraldton',
#  'hithadhoo',
#  'itarema',
#  'dikson',
#  'barentsburg',
#  'poum',
#  'yar-sale',
#  'klyuchi',
#  'senanga',
#  'yumen',
#  'klaksvik',
#  'eyl',
#  'port elizabeth',
#  'cape town',
#  'addis abeba',
#  'ahipara',
#  'lufilufi',
#  'la ronge',
#  'richards bay',
#  'provideniya',
#  'karratha',
#  'ler',
#  'forchheim',
#  'half moon bay',
#  'boali',
#  'nome',
#  'tateyama',
#  'saint-pierre',
#  'saskylakh',
#  'iracoubo',
#  'launceston',
#  'luis gil perez',
#  'lazurne',
#  'beyneu',
#  'corinth',
#  'nishihara',
#  'deputatskiy',
#  'ewa beach',
#  'vardo',
#  'natitingou',
#  'kijang',
#  'palauig',
#  'yellowknife',
#  'voh',
#  'bawku',
#  'hami',
#  'rutana',
#  'wattegama',
#  'savannah bight',
#  'jalingo',
#  'kaeo',
#  'bilma',
#  'tazovskiy',
#  'chapais',
#  'akyab',
#  'sitka',
#  'talnakh',
#  'rocha',
#  'cullman',
#  'alta',
#  'hirara',
#  'torbay',
#  'tukan',
#  'baft',
#  'jalu',
#  'tuktoyaktuk',
#  'muncar',
#  'bubaque',
#  'salalah',
#  'yoichi',
#  'taoudenni',
#  'porbandar',
#  'pechora',
#  'goderich',
#  'naze',
#  'tual',
#  'zharkent',
#  'cabo san lucas',
#  'bengkulu',
#  'roros',
#  'marcona',
#  'bria',
#  'portland',
#  'san juan',
#  'rajbiraj',
#  'lata',
#  'pevek',
#  'coahuayana',
#  'isangel',
#  'cheuskiny',
#  'mys shmidta',
#  'okhotsk',
#  'hobyo',
#  'port alfred',
#  'ruwi',
#  'mercedes',
#  'lazaro cardenas',
#  'norman wells',
#  'benghazi',
#  'attawapiskat',
#  'flin flon',
#  'brest',
#  'soyo',
#  'vestmanna',
#  'nicoya',
#  'formoso do araguaia',
#  'barcelos',
#  'pacific grove',
#  'harper',
#  'bocaiuva',
#  'mahebourg',
#  'whitehorse',
#  'xuanhua',
#  'hermanus',
#  'yulara',
#  'malumfashi',
#  'changping',
#  'chifeng',
#  'cherskiy',
#  'zilupe',
#  'bumba',
#  'manikpur',
#  'alta floresta',
#  'anadyr',
#  'airai',
#  'kavieng',
#  'wewak',
#  'udachnyy',
#  'jiblah',
#  'bambous virieux',
#  'umea',
#  'seoul',
#  'altay',
#  'gizo',
#  'batagay-alyta',
#  'hurghada',
#  'miles city',
#  'paiho',
#  'pozo colorado',
#  'yarmouth',
#  'vallenar',
#  'caravelas',
#  'adrar',
#  'rio gallegos',
#  'thetford mines',
#  'ruatoria',
#  'taksimo',
#  'xiaoweizhai',
#  'mitchell',
#  'seymchan',
#  'lodwar',
#  'innisfail',
#  'great bend',
#  'viedma',
#  'mount gambier',
#  'nizhneyansk',
#  'lingao',
#  'meulaboh',
#  'coquimbo',
#  'suntar',
#  'san cristobal',
#  'port keats',
#  'constitucion',
#  'faanui',
#  'hasaki',
#  'pringsewu',
#  'ponta do sol',
#  'along',
#  'azangaro',
#  'sedelnikovo',
#  'los llanos de aridane',
#  'wilmington',
#  'ostrovnoy',
#  'mahibadhoo',
#  'phuntsholing',
#  'horki',
#  'kuldiga',
#  'novotroitskaya',
#  'mina',
#  'samusu',
#  'mehamn',
#  'port macquarie',
#  'sangueya',
#  'pasighat',
#  'dvinskoy',
#  'vicuna',
#  'palmital',
#  'khandyga',
#  'povenets',
#  'mtwara',
#  'vaitupu',
#  'palabuhanratu',
#  'devyatka',
#  'vrangel',
#  'fairbanks',
#  'dzilam gonzalez',
#  'aksu',
#  'vao',
#  'luderitz',
#  'saint-georges',
#  'oyama',
#  'guerrero negro',
#  'evensk',
#  'nha trang',
#  'awbari',
#  'lorengau',
#  'victoria',
#  'yining',
#  'misratah',
#  'lagoa',
#  'bukachacha',
#  'aksha',
#  'yafran',
#  'coihaique',
#  'bolungarvik',
#  'bardiyah',
#  'trapani',
#  'san quintin',
#  'lastoursville',
#  'birjand',
#  'tura',
#  'carballo',
#  'nouadhibou',
#  'nador',
#  'lompoc',
#  'kirakira',
#  'umzimvubu',
#  'brookhaven',
#  'jacareacanga',
#  'longyearbyen',
#  'nuuk',
#  'manzhouli',
#  'oranjemund',
#  'ambilobe',
#  'zhanatas',
#  'pangnirtung',
#  'lerwick',
#  'biak',
#  'sao filipe',
#  'buariki',
#  'petropavlivka',
#  'asyut',
#  'palmer',
#  'chikwawa',
#  'pitimbu',
#  'bataipora',
#  'presidencia roque saenz pena',
#  'vila franca do campo',
#  'kuchinarai',
#  'teguldet',
#  'tome',
#  'sioux lookout',
#  'hihifo',
#  'nikolskoye',
#  'moose factory',
#  'pisco',
#  'shchelyayur',
#  'zaragoza',
#  'karpogory',
#  'todos santos',
#  'tocopilla',
#  'uzhur',
#  'abu kamal',
#  'trinidad',
#  'qaqortoq',
#  'preston',
#  'sur',
#  'buqayq',
#  'bago',
#  'carutapera',
#  'oussouye',
#  'dukat',
#  'pandamatenga',
#  'middle island',
#  'comodoro rivadavia',
#  'sentyabrskiy',
#  'vostok',
#  'husavik',
#  'chunoyar',
#  'batie',
#  'amderma',
#  'semporna',
#  'bintulu',
#  'korampallam',
#  'tessalit',
#  'mayna',
#  'mayo',
#  'bulancak',
#  'grindavik',
#  'bandarbeyla',
#  'alofi',
#  'byron bay',
#  'gamba',
#  'jaten',
#  'mrirt',
#  'tabou',
#  'port hedland',
#  'labuan',
#  'walla walla',
#  'buenos aires',
#  'bloomington',
#  'lock haven',
#  'uyuni',
#  'tromso',
#  'manavalakurichi',
#  'nguiu',
#  'muros',
#  'cheremkhovo',
#  'yerbogachen',
#  'doctor pedro p. pena',
#  'kosa',
#  'pervomayskoye',
#  'santa isabel',
#  'nakusp',
#  'mankono',
#  'manzanillo',
#  'grand river south east',
#  'fortuna',
#  'souris',
#  'klisura',
#  'harnosand',
#  'paraguacu',
#  'haizhou',
#  'santiago',
#  'safranbolu',
#  'wukari',
#  'zhangjiakou',
#  'rungata',
#  'mezen',
#  'saint anthony',
#  'abu dhabi',
#  'broome',
#  'kahului',
#  'suluq',
#  'moquegua',
#  'high level',
#  'kpandu',
#  'ngukurr',
#  'hede',
#  'kulu',
#  'vossevangen',
#  'hofn',
#  'tawkar',
#  'yarkovo',
#  'noumea',
#  'mitsamiouli',
#  'ijaki',
#  'souillac',
#  'pastavy',
#  'maningrida',
#  'tucuman',
#  'kilindoni',
#  'makakilo city',
#  'azimur',
#  'duldurga',
#  'long xuyen',
#  'chuy',
#  'tautira',
#  'svetlyy',
#  'santa rosa',
#  'teguise',
#  'talcahuano',
#  'baykit',
#  'saldanha',
#  'porto novo',
#  'lagos',
#  'rawson',
#  'svetlogorsk',
#  'khanewal',
#  'natal',
#  'kokopo',
#  'port lavaca',
#  'kieta',
#  'itoman',
#  'sao miguel do araguaia',
#  'lekoni',
#  'swan hill',
#  'kyzyl-suu',
#  'iralaya',
#  'saint george',
#  'shetpe',
#  'bomi',
#  'severnyy',
#  'yashkul',
#  'kangaatsiaq',
#  'oltu',
#  'halalo',
#  'goiatuba',
#  'paragominas',
#  'dubti',
#  'nanortalik',
#  'gari',
#  'haines junction',
#  'san patricio',
#  'padang',
#  'solnechnyy',
#  'kirovskiy',
#  'cherdyn',
#  'alekseyevka',
#  'tres arroyos',
#  'suleja',
#  'posse',
#  'buala',
#  'coutances',
#  'sechura',
#  'montepuez',
#  'puerto penasco',
#  'westport',
#  'halifax',
#  'price',
#  'semey',
#  'srostki',
#  'aitape',
#  'shambu',
#  'matagami',
#  'westbrook',
#  'aiquile',
#  'ladario',
#  'loandjili',
#  'sungaipenuh',
#  'xam nua',
#  'marzuq',
#  'grand gaube',
#  'mazyr',
#  'caohe',
#  'sisimiut',
#  'qasigiannguit',
#  'yandyki',
#  'sydney',
#  'massaguet',
#  'port-cartier',
#  'ancud',
#  'kouango',
#  'bolshevik',
#  'gijon',
#  'bonoua',
#  'dolbeau',
#  'nortelandia',
#  'quelimane',
#  'vreed en hoop',
#  'sao tome',
#  'faya',
#  'pizarro',
#  'jaque',
#  'araouane',
#  'banda aceh',
#  'baoding',
#  'sahrak',
#  'sorvag',
#  'brownwood',
#  'gavle',
#  'kolokani',
#  'conneaut',
#  'marawi',
#  'paradwip',
#  'russell',
#  'huarmey',
#  'severo-kurilsk',
#  'umm durman',
#  'indramayu',
#  'longhua',
#  'harur',
#  'gilgit',
#  'bagamoyo',
#  'katobu',
#  'auki',
#  'kasongo-lunda',
#  'cumbitara',
#  'pereslavl-zalesskiy',
#  'chernyakhovsk',
#  'bath',
#  'laives',
#  'dakar',
#  'namibe',
#  'nhulunbuy',
#  'amreli',
#  'mackay',
#  'chipoka',
#  'owando',
#  'teya',
#  'tairua',
#  'gornopravdinsk',
#  'khormuj',
#  'barao de melgaco',
#  'quatre cocos',
#  'midyat']
